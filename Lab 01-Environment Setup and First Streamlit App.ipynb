# %% [markdown]
# # 🎓 Lab 01: Environment Setup and First Streamlit App
#
# Web App Development for Data Science — Student Version

# %% [markdown]
# ## 🎯 About This Lab
#
# **Skill:** `Environment Setup + First Streamlit App`
# **Version:** `v1.0`
# **Main Tool:** `Python / VS Code / Streamlit`
# **Project Theme:** `EduRisk Analytics`
# **Chapter:** `Chapter 01: Environment Setup and First Streamlit App`
#
# In this lab, you will set up a Python environment and create your first Streamlit app.
#
# You will learn how to:
#
# - Check Python and pip
# - Create a project folder
# - Create a virtual environment
# - Install Streamlit and Pandas
# - Build a simple Streamlit app
# - Display student data
# - Show dashboard metrics

# %% [markdown]
# ## 📌 Final Lab Output
#
# At the end of this lab, your folder should contain:
#
# ```text
# lab01-first-streamlit-app/
# ├── app.py
# ├── requirements.txt
# └── README.md
# ```
#
# Do not submit:
#
# ```text
# .venv/
# __pycache__/
# ```

# %% [markdown]
# # Step 1: Check Python
# ## What you will do
#
# Check whether Python is installed on your computer.
#
# ## Command
#
# ```bash
# python --version
# ```
#
# If it does not work, try:
#
# ```bash
# python3 --version
# ```
#
# ## Expected Result
#
# ```text
# Python 3.10.0
# ```
#
# or newer.

# %%
# !python --version
# Out:
# Python 3.13.13

# %% [markdown]
# # Step 2: Check pip
#
# ## What you will do
#
# Check whether pip is installed.
#
# ## Command
#
# ```bash
# pip --version
# ```
#
# If it does not work, try:
#
# ```bash
# python -m pip --version
# ```
#
# ## Expected Result
#
# ```text
# pip 23.x.x
# ```

# %%
pip --version
# Out:
# pip 26.0.1 from c:\Users\Seng Thay\AppData\Local\Programs\Python\Python313\Lib\site-packages\pip (python 3.13)
#
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# # Step 3: Create Project Folder
#
# ## What you will do
#
# Create a folder for Lab 01.
#
# ## Command
#
# ```bash
# mkdir lab01-first-streamlit-app
# cd lab01-first-streamlit-app
# ```
#
# ## Expected Result
#
# You are now inside the project folder:
#
# ```text
# lab01-first-streamlit-app
# ```

# %%
from pathlib import Path

project_dir = Path.cwd() / "lab01-first-streamlit-app"
project_dir.mkdir(exist_ok=True)
# %cd {project_dir}
# Out:
#   Cell In[5], line 1
#     mkdir lab01-first-streamlit-app
#           ^
# SyntaxError: invalid syntax

# %% [markdown]
# # Step 4: Open Folder in VS Code
#
# ## What you will do
#
# Open the project folder in VS Code.
#
# ## Command
#
# ```bash
# code .
# ```
#
# ## Note
#
# If `code .` does not work, open VS Code manually and select this folder:
#
# ```text
# lab01-first-streamlit-app
# ```

# %% [markdown]
# # Step 5: Create Virtual Environment
#
# ## What you will do
#
# Create a virtual environment for this project.
#
# ## Command
#
# ```bash
# python -m venv .venv
# ```
#
# If needed, use:
#
# ```bash
# python3 -m venv .venv
# ```
#
# ## Expected Result
#
# A new folder is created:
#
# ```text
# .venv/
# ```
#
# ## Why This Step Matters
#
# A virtual environment helps you:
#
# - Keep packages separate
# - Avoid package conflicts
# - Manage project dependencies

# %% [markdown]
# # Step 6: Activate Virtual Environment
#
# ## What you will do
#
# Activate the virtual environment.
#
# ## Windows PowerShell
#
# ```powershell
# .venv\Scripts\Activate.ps1
# ```
#
# ## Windows Command Prompt
#
# ```cmd
# .venv\Scripts\activate
# ```
#
# ## macOS / Linux
#
# ```bash
# source .venv/bin/activate
# ```
#
# ## Expected Result
#
# Your terminal should show:
#
# ```text
# (.venv)
# ```
#
# Example:
#
# ```text
# (.venv) PS C:\Users\Student\lab01-first-streamlit-app>
# ```

# %% [markdown]
# # Step 7: PowerShell Activation Fix
#
# ## What you will do
#
# If Windows PowerShell blocks virtual environment activation, allow script execution for the current user.
#
# ## Command
#
# ```powershell
# Set-ExecutionPolicy -ExecutionPolicy RemoteSigned -Scope CurrentUser
# ```
#
# Then activate the virtual environment again:
#
# ```powershell
# .venv\Scripts\Activate.ps1
# ```
#
# ## Note
#
# Only do this step if PowerShell shows an activation error.

# %% [markdown]
# # Step 8: Install Streamlit and Pandas
#
# ## What you will do
#
# Install the required Python packages.
#
# ## Command
#
# ```bash
# pip install streamlit pandas
# ```
#
# ## Package Purpose
#
# | Package | Purpose |
# |---|---|
# | `streamlit` | Build web apps using Python |
# | `pandas` | Work with data tables |

# %% [markdown]
# # Step 9: Check Streamlit Installation
#
# ## What you will do
#
# Check whether Streamlit is installed correctly.
#
# ## Command
#
# ```bash
# streamlit --version
# ```
#
# ## Expected Result
#
# ```text
# Streamlit, version 1.x.x
# ```

# %% [markdown]
# # Step 10: Create Project Files
#
# ## What you will do
#
# Create three files in your project folder.
#
# ## Files to Create
#
# ```text
# app.py
# requirements.txt
# README.md
# ```
#
# ## Expected Folder Structure
#
# ```text
# lab01-first-streamlit-app/
# ├── app.py
# ├── requirements.txt
# └── README.md
# ```

# %% [markdown]
# # Step 11: Write `requirements.txt`
#
# ## What you will do
#
# Add the required package names to `requirements.txt`.
#
# ## File
#
# ```text
# requirements.txt
# ```
#
# ## Content
#
# ```text
# streamlit
# pandas
# ```
#
# ## Purpose
#
# This file tells other users which packages your project needs.

# %% [markdown]
# # Step 12: Create the Streamlit App
#
# ## What you will do
#
# Write the main application code in `app.py`.
#
# ## File
#
# ```text
# app.py
# ```
#
# ## Code
#
# ```python
# import streamlit as st
# import pandas as pd
#
# st.set_page_config(
#     page_title="EduRisk Analytics - Lab 01",
#     page_icon="🎓",
#     layout="centered"
# )
#
# student_df = pd.DataFrame({
#     "Student Name": ["Dara", "Sophea", "Vuthy", "Malis", "Rithy"],
#     "Course": ["Python", "Statistics", "Python", "Database", "Web App"],
#     "Score": [85, 68, 45, 92, 58],
#     "Attendance": [90, 75, 50, 95, 60],
#     "Study Hours": [12, 8, 3, 15, 5]
# })
#
# total_students = len(student_df)
# average_score = student_df["Score"].mean()
# average_attendance = student_df["Attendance"].mean()
# low_score_students = student_df[student_df["Score"] < 60].shape[0]
#
# with st.sidebar:
#     st.title("EduRisk Menu")
#     selected_page = st.radio(
#         "Select Page",
#         ["Home", "Student Data", "About"]
#     )
#
# if selected_page == "Home":
#     st.title("🎓 EduRisk Analytics")
#     st.subheader("Student Risk Prediction and Monitoring System")
#     st.write("Welcome to your first Streamlit web application.")
#     st.success("Streamlit is working successfully!")
#
# elif selected_page == "Student Data":
#     st.title("Student Data")
#
#     col1, col2 = st.columns(2)
#
#     with col1:
#         st.metric("Total Students", total_students)
#         st.metric("Average Score", round(average_score, 2))
#
#     with col2:
#         st.metric("Average Attendance", f"{round(average_attendance, 2)}%")
#         st.metric("Low Score Students", low_score_students)
#
#     st.dataframe(student_df)
#
# else:
#     st.title("About")
#     st.write("This app is part of Lab 01.")
#     st.write("Course: Web App Development for Data Science")
#     st.write("Project Theme: EduRisk Analytics")
# ```

# %% [markdown]
# # Step 13: Run the App
#
# ## What you will do
#
# Run your Streamlit app from the terminal.
#
# ## Command
#
# ```bash
# streamlit run app.py
# ```
#
# ## Expected Result
#
# The app opens in your browser.
#
# URL:
#
# ```text
# http://localhost:8501
# ```

# %% [markdown]
# # Step 14: Stop the App
#
# ## What you will do
#
# Stop the running Streamlit app.
#
# ## Command
#
# Press:
#
# ```text
# Ctrl + C
# ```

# %% [markdown]
# # Step 15: Check the Home Page
#
# ## What you will do
#
# Check the Home page of your app.
#
# ## Expected Output
#
# The Home page should show:
#
# - EduRisk Analytics
# - Student Risk Prediction and Monitoring System
# - Welcome message
# - Success message

# %% [markdown]
# # Step 16: Check the Student Data Page
#
# ## What you will do
#
# Click `Student Data` in the sidebar.
#
# ## Expected Output
#
# The page should show:
#
# - Total Students
# - Average Score
# - Average Attendance
# - Low Score Students
# - Student data table
#
# ## Expected Metrics
#
# | Metric | Value |
# |---|---:|
# | Total Students | 5 |
# | Average Score | 69.6 |
# | Average Attendance | 74.0% |
# | Low Score Students | 2 |

# %% [markdown]
# # Step 17: Check the About Page
#
# ## What you will do
#
# Click `About` in the sidebar.
#
# ## Expected Output
#
# The About page should show:
#
# - This app is part of Lab 01.
# - Course: Web App Development for Data Science
# - Project Theme: EduRisk Analytics

# %% [markdown]
# # Step 18: Write `README.md`
#
# ## What you will do
#
# Write project information in `README.md`.
#
# ## File
#
# ```text
# README.md
# ```
#
# ## Content
#
# ```markdown
# # Lab 01: First Streamlit App
#
# ## Project Theme
#
# EduRisk Analytics
#
# ## Description
#
# This is my first Streamlit web app.
#
# ## Features
#
# - Sidebar navigation
# - Student data table
# - Dashboard metrics
#
# ## Tools Used
#
# - Python
# - Streamlit
# - Pandas
# - VS Code
#
# ## How to Run
#
# streamlit run app.py
#
# ## Student Information
#
# Name:
# Student ID:
# Class:
# ```

# %% [markdown]
# # Step 19: Prepare Submission
#
# ## What you will do
#
# Prepare your files for submission.
#
# ## Submit These Files
#
# ```text
# app.py
# requirements.txt
# README.md
# ```
#
# ## Do Not Submit
#
# ```text
# .venv/
# __pycache__/
# ```

# %% [markdown]
# # Step 20: Create Zip File
#
# ## What you will do
#
# Compress your project files into one zip file.
#
# ## Zip File Name Format
#
# ```text
# studentid_name_lab01.zip
# ```
#
# ## Example
#
# ```text
# e20230001_dara_lab01.zip
# ```

# %% [markdown]
# # Step 21: Final Checklist
#
# ## Before submitting, check:
#
# - [ ] `app.py` exists
# - [ ] `requirements.txt` exists
# - [ ] `README.md` exists
# - [ ] App runs with `streamlit run app.py`
# - [ ] Sidebar has Home, Student Data, and About
# - [ ] Student Data page shows metrics
# - [ ] Student Data page shows a table
# - [ ] `.venv/` is not included
# - [ ] `__pycache__/` is not included

# %% [markdown]
# # 🧾 Grading Rubric
#
# Total score:
#
# ```text
# 100 points
# ```
#
# | Criteria | Points |
# |---|---:|
# | Correct project files | 15 |
# | Virtual environment used | 10 |
# | Packages installed | 10 |
# | App runs successfully | 20 |
# | Sidebar navigation works | 10 |
# | Student data table displays | 10 |
# | Dashboard metrics display | 10 |
# | README.md completed | 10 |
# | Clean submission zip file | 5 |
# | **Total** | **100** |

# %% [markdown]
# # 🛠️ Common Problems and Fixes
#
# ## Problem 1: `python` is not recognized
#
# Try:
#
# ```bash
# python3 --version
# ```
#
# ---
#
# ## Problem 2: `pip` is not recognized
#
# Try:
#
# ```bash
# python -m pip --version
# ```
#
# ---
#
# ## Problem 3: `streamlit` is not recognized
#
# Make sure your virtual environment is activated.
#
# Then run:
#
# ```bash
# pip install streamlit
# ```
#
# ---
#
# ## Problem 4: Browser does not open
#
# Open this URL manually:
#
# ```text
# http://localhost:8501
# ```
#
# ---
#
# ## Problem 5: App does not update
#
# Try:
#
# ```text
# Save app.py
# Refresh browser
# Check terminal error message
# ```

# %% [markdown]
# # 🧩 Code Block Style Guide
#
# Use the correct Markdown code block style:
#
# | Content Type | Use |
# |---|---|
# | General terminal command | `bash` |
# | Windows PowerShell command | `powershell` |
# | Windows Command Prompt command | `cmd` |
# | Python code | `python` |
# | README.md content | `markdown` |
# | Output, URLs, filenames, folder structures | `text` |
#
# ## Examples
#
# General terminal command:
#
# ```bash
# streamlit run app.py
# ```
#
# Windows PowerShell command:
#
# ```powershell
# .venv\Scripts\Activate.ps1
# ```
#
# Windows CMD command:
#
# ```cmd
# .venv\Scripts\activate
# ```
#
# Python code:
#
# ```python
# print("Hello Streamlit")
# ```
#
# Expected output:
#
# ```text
# Hello Streamlit
# ```

# %% [markdown]
# # 💡 Tip
#
# Always activate your virtual environment before installing packages or running the app.
#
# Do not submit the `.venv/` folder.
#
# Save your files before running the app again.
